# %%
import pandas as pd

# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\as296\\Desktop\\MLOps\\YT_Insights\\Experiments'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\as296\\Desktop\\MLOps\\YT_Insights'

# %%
df = pd.read_csv('./data/raw/train_data.csv')

# %%
df
# Out:
#                                            clean_comment  category
# 0                      found young modi guess which one          1
# 1      holy shit heard the whole johnny gosch story e...         0
# 2      porra tava amando ler isso poderia pelo menos ...         0
# 3      mmw will have something witty add this thread ...         1
# 4       have similar chart for call quality would lov...         0
# ...                                                  ...       ...
# 29429   would just saying msm cant sensetionalize peo...        -1
# 29430  india will have counter strike team major atle...         1
# 29431  well think just like family member the same li...         0
# 29432  this very good stuff thank you for taking the ...         1
# 29433                                            perchè          0
#
# [29434 rows x 2 columns]
